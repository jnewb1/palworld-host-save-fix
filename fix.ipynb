# %%
# !cargo install --git https://github.com/trumank/uesave-rs.git
# Out:
#     Updating git repository `https://github.com/trumank/uesave-rs.git`
#   Installing uesave v0.3.0 (https://github.com/trumank/uesave-rs.git#68442f11)
#     Updating crates.io index
#   Downloaded cfg-if v1.0.0
#   Downloaded bitflags v2.4.2ng bytes: 41.5 KB
#   Downloaded clap_derive v4.4.7bytes: 12.3 KB
#   Downloaded ryu v1.0.16aining bytes: 12.3 KB
#   Downloaded equivalent v1.0.1 bytes: 85.7 KB
#   Downloaded itoa v1.0.10ining bytes: 2.3 MB
#   Downloaded clap_lex v0.6.0ng bytes: 3.9 MB
#   Downloaded fastrand v2.0.1ng bytes: 3.9 MB
#   Downloaded either v1.9.0ning bytes: 3.9 MB
#   Downloaded strsim v0.10.0ing bytes: 3.9 MB
#   Downloaded shell-words v1.1.0bytes: 3.9 MB
#   Downloaded colorchoice v1.0.0bytes: 3.9 MB
#   Downloaded byteorder v1.5.0g bytes: 3.8 MB
#   Downloaded anstyle v1.0.4ing bytes: 3.7 MB
#   Downloaded errno v0.3.8ining bytes: 3.7 MB
#   Downloaded edit v0.1.5aining bytes: 3.7 MB
#   Downloaded home v0.5.9aining bytes: 3.6 MB
# ...

# %%
WORLD_PATH = "76561198136043776/60AF4D3741874457158EDCA0A5C2843D"

# %%
# !cd data && rm -rf {SAVEPATH} && unzip world.zip
# Out:
# Archive:  world.zip
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.22-20.59.52/
#  extracting: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.22-20.59.52/LocalData.sav
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.22-21.59.52/
#  extracting: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.22-21.59.52/LocalData.sav
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.22-22.39.22/
#  extracting: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.22-22.39.22/LocalData.sav
#    creating: 76561198136043776/60AF4D3741874457158EDCA0A5C2843D/backup/local/2024.01.23-19.59.36/
# ...

# %%
# !which uesave
# Out:
# /usr/local/cargo/bin/uesave

# %%
NEW_GUID = "648A6CA6000000000000000000000000" # ?? need this ??
OLD_GUID = "00000000000000000000000000000001"

# %%
# !python fix_host_save.py /usr/local/cargo/bin/uesave data/{WORLD_PATH} {NEW_GUID} {OLD_GUID}
# Out:
# ERROR: Your player save does not exist. Did you enter the correct new GUID of your player? It should look like "8E910AC2000000000000000000000000".
# Did your player create their character with the provided save? Once they create their character, a file called "data/76561198136043776/60AF4D3741874457158EDCA0A5C2843D/Players/648A6CA6000000000000000000000000.sav" should appear. Look back over the steps in the README on how to get your new GUID.
